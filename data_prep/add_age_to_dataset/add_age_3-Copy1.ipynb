# %% [markdown]
# # Combining age with other attributes

# %%
import cudf
import pyarrow as pa
import pandas as pd
import numpy as np
import cupy as cp
import os

# %%
os.environ['CUDA_VISIBLE_DEVICES'] = "0"

# %%
df = cudf.read_parquet('../data/all_states_lat_long_cow_income_education_age_sex.parquet/*')

# %%
df.drop_column('age')

# %%
df.x = df.x.astype('float32')
df.y = df.y.astype('float32')

# %%
df = df.sort_values('GISJOIN')
df
# Out:
#                      GISJOIN           x           y  sex       p_id  \
# 49440       1000100201001000  -9626773.0  3824702.25    1         35
# 49441       1000100201001000  -9627132.0  3824709.25    1         36
# 49442       1000100201001000  -9626740.0  3825409.00    1         37
# 49443       1000100201001000  -9627007.0  3825576.00    1         38
# 49444       1000100201001000  -9626684.0  3825259.75    1         39
# ...                      ...         ...         ...  ...        ...
# 308742648  56004509513003128 -11599208.0  5441573.00    1  308745304
# 308742649  56004509513003128 -11599316.0  5441618.00    1  308745305
# 308742650  56004509513003128 -11599414.0  5441687.00    1  308745306
# 308742651  56004509513003128 -11599409.0  5441688.50    1  308745307
# 308742652  56004509513003128 -11599264.0  5441574.00    1  308745308
#
#            education  income  cow
# 49440              0      19    0
# 49441              0      19    0
# 49442              0      19    0
# 49443              0      19    0
# 49444              0      19    0
# ...              ...     ...  ...
# 308742648         12       4    0
# 308742649         12       4    0
# 308742650         12       4    0
# 308742651         12       4    0
# 308742652         12       4    0
#
# [308745309 rows x 8 columns]

# %%
df_age = cudf.read_parquet('./age_step_2.parquet/*')

# %%
df_age = df_age.sort_values('GISJOIN').reset_index()
df_age.drop_column('index')

# %%
df_age
# Out:
#                   GISJOIN  age
# 0           1000100201001    1
# 1           1000100201001    1
# 2           1000100201001    4
# 3           1000100201001    2
# 4           1000100201001    1
# ...                   ...  ...
# 308745304  56004509513003   85
# 308745305  56004509513003   85
# 308745306  56004509513003   85
# 308745307  56004509513003   85
# 308745308  56004509513003   85
#
# [308745309 rows x 2 columns]

# %%
df_age_with_gis_mappings = cudf.read_parquet('./GISJOIN_to_GISJOIN_og_mapping.parquet/*')
df_age_with_gis_mappings.drop_column('sex')

# %%
df_age_with_gis_mappings = df_age_with_gis_mappings.sort_values('GISJOIN').reset_index()
df_age_with_gis_mappings.drop_column('index')

# %%
df_age_with_gis_mappings.drop_column('GISJOIN_og')

# %%
df_age_with_gis_mappings
# Out:
#                 p_id         GISJOIN
# 0                576   1000100201001
# 1                577   1000100201001
# 2                578   1000100201001
# 3                579   1000100201001
# 4                580   1000100201001
# ...              ...             ...
# 308745304  308744475  56004509513003
# 308745305  308744476  56004509513003
# 308745306  308744477  56004509513003
# 308745307  308744478  56004509513003
# 308745308  308744479  56004509513003
#
# [308745309 rows x 2 columns]

# %%
df_age_with_gis_mappings['GISJOIN_age'] = df_age.GISJOIN.values

# %%
df_age_with_gis_mappings.query('GISJOIN != GISJOIN_age')
# Out:
# Empty DataFrame
# Columns: [p_id, GISJOIN, GISJOIN_age]
# Index: []

# %%
df_age_with_gis_mappings['age'] = df_age.age.values

# %%
df_age_with_gis_mappings.drop_column('GISJOIN_age')
df_age_with_gis_mappings.drop_column('GISJOIN')

# %%
del(df_age)

# %%
df_age_with_gis_mappings
# Out:
#                 p_id  age
# 0                576    1
# 1                577    1
# 2                578    4
# 3                579    2
# 4                580    1
# ...              ...  ...
# 308745304  308744475   85
# 308745305  308744476   85
# 308745306  308744477   85
# 308745307  308744478   85
# 308745308  308744479   85
#
# [308745309 rows x 2 columns]

# %% [markdown]
# ### merge sex and age with lat-long table

# %%
df.head()
# Out:
#                 GISJOIN          x           y  sex  p_id  education  income  \
# 49440  1000100201001000 -9626773.0  3824702.25    1    35          0      19
# 49441  1000100201001000 -9627132.0  3824709.25    1    36          0      19
# 49442  1000100201001000 -9626740.0  3825409.00    1    37          0      19
# 49443  1000100201001000 -9627007.0  3825576.00    1    38          0      19
# 49444  1000100201001000 -9626684.0  3825259.75    1    39          0      19
#
#        cow
# 49440    0
# 49441    0
# 49442    0
# 49443    0
# 49444    0

# %%
df = df.merge(df_age_with_gis_mappings, on='p_id', how='inner')

# %%
df
# Out:
#                      GISJOIN           x           y  sex       p_id  \
# 0           1000100207002017  -9623904.0  3823389.75    0      29042
# 1           1000100207002017  -9623795.0  3823349.75    0      29043
# 2           1000100207002017  -9623942.0  3823424.00    0      29044
# 3           1000100207002017  -9623815.0  3823353.50    0      29045
# 4           1000100207002017  -9623835.0  3823438.75    1      29046
# ...                      ...         ...         ...  ...        ...
# 308745304  56004509511002136 -11593976.0  5456722.50    1  308739960
# 308745305  56004509511002136 -11598623.0  5457926.50    1  308739961
# 308745306  56004509511002136 -11598757.0  5458250.50    1  308739962
# 308745307  56004509511002136 -11598786.0  5456930.50    1  308739963
# 308745308  56004509511002136 -11598612.0  5457813.50    1  308739964
#
#            education  income  cow  age
# 0                 10      12    0   45
# 1                 10      12    0   49
# 2                 10      12    0   45
# 3                 10      12    0   48
# 4                 10       0    0   48
# ...              ...     ...  ...  ...
# 308745304          5       5    0   45
# 308745305          5       5    2   46
# 308745306          5       5    2   46
# 308745307          5       5    2   46
# 308745308          5       5    2   47
#
# [308745309 rows x 9 columns]

# %%
df.dtypes
# Out:
# GISJOIN        int64
# x            float32
# y            float32
# sex             int8
# p_id           int32
# education       int8
# income          int8
# cow             int8
# age            int64
# dtype: object

# %%
df.age = df.age.astype('int8')

# %%
df
# Out:
#                      GISJOIN           x           y  sex       p_id  \
# 0           1000100207002017  -9623904.0  3823389.75    0      29042
# 1           1000100207002017  -9623795.0  3823349.75    0      29043
# 2           1000100207002017  -9623942.0  3823424.00    0      29044
# 3           1000100207002017  -9623815.0  3823353.50    0      29045
# 4           1000100207002017  -9623835.0  3823438.75    1      29046
# ...                      ...         ...         ...  ...        ...
# 308745304  56004509511002136 -11593976.0  5456722.50    1  308739960
# 308745305  56004509511002136 -11598623.0  5457926.50    1  308739961
# 308745306  56004509511002136 -11598757.0  5458250.50    1  308739962
# 308745307  56004509511002136 -11598786.0  5456930.50    1  308739963
# 308745308  56004509511002136 -11598612.0  5457813.50    1  308739964
#
#            education  income  cow  age
# 0                 10      12    0   45
# 1                 10      12    0   49
# 2                 10      12    0   45
# 3                 10      12    0   48
# 4                 10       0    0   48
# ...              ...     ...  ...  ...
# 308745304          5       5    0   45
# 308745305          5       5    2   46
# 308745306          5       5    2   46
# 308745307          5       5    2   46
# 308745308          5       5    2   47
#
# [308745309 rows x 9 columns]

# %%
df.to_parquet('../data/all_states_lat_long_cow_income_education_age_sex.parquet')
# Out:
# /home/ajay/anaconda3/envs/rapids_dev_0.12/lib/python3.6/site-packages/cudf/io/parquet.py:70: UserWarning: Using CPU via PyArrow to write Parquet dataset, this will be GPU accelerated in the future
#   "Using CPU via PyArrow to write Parquet dataset, this will "

# %% [markdown]
# # Combining cow with other attributes

# %%
import cudf
import pyarrow as pa
import pandas as pd
import numpy as np
import cupy as cp
import os

# %%
os.environ['CUDA_VISIBLE_DEVICES'] = "0"

# %%
df = cudf.read_parquet('../data/all_states_lat_long_income_education_age_sex.parquet/*')

# %%
df = df.sort_values('GISJOIN')
df
# Out:
#                      GISJOIN             x             y  sex       p_id  age  \
# 52128       1000100201001000 -9.626773e+06  3.824702e+06    1         35   49
# 52129       1000100201001000 -9.627132e+06  3.824709e+06    1         36   46
# 52130       1000100201001000 -9.626740e+06  3.825409e+06    1         37   48
# 52131       1000100201001000 -9.627007e+06  3.825576e+06    1         38   48
# 52132       1000100201001000 -9.626684e+06  3.825260e+06    1         39   47
# ...                      ...           ...           ...  ...        ...  ...
# 308729240  56004509513003128 -1.159921e+07  5.441573e+06    1  308745304   35
# 308729241  56004509513003128 -1.159932e+07  5.441618e+06    1  308745305   35
# 308729242  56004509513003128 -1.159941e+07  5.441687e+06    1  308745306   38
# 308729243  56004509513003128 -1.159941e+07  5.441688e+06    1  308745307   35
# 308729244  56004509513003128 -1.159926e+07  5.441574e+06    1  308745308   35
#
#            education  income
# 52128              0      19
# 52129              0      19
# 52130              0      19
# 52131              0      19
# 52132              0      19
# ...              ...     ...
# 308729240         12       4
# 308729241         12       4
# 308729242         12       4
# 308729243         12       4
# 308729244         12       4
#
# [308745309 rows x 8 columns]

# %%
df.dtypes
# Out:
# GISJOIN        int64
# x            float64
# y            float64
# sex             int8
# p_id           int32
# age             int8
# education       int8
# income          int8
# dtype: object

# %%
df_cow = cudf.read_parquet('./cow_step_2.parquet/*')

# %%
df_cow.cow = df_cow.cow.astype('int8')
df_cow = df_cow.sort_values('GISJOIN').reset_index()
df_cow.drop_column('index')

# %%
df_cow.dtypes
# Out:
# GISJOIN    int64
# cow         int8
# dtype: object

# %%
df_cow
# Out:
#                   GISJOIN  cow
# 0           1000100201001    0
# 1           1000100201001    0
# 2           1000100201001    0
# 3           1000100201001    0
# 4           1000100201001    0
# ...                   ...  ...
# 243227903  56004509513003    6
# 243227904  56004509513003    6
# 243227905  56004509513003    6
# 243227906  56004509513003    6
# 243227907  56004509513003    6
#
# [243227908 rows x 2 columns]

# %%
df_cow_with_gis_mappings = cudf.read_parquet('./GISJOIN_to_GISJOIN_og_mapping.parquet/*')
df_cow_with_gis_mappings.age = df_cow_with_gis_mappings.age.astype('int8')

# %%
df_cow_with_gis_mappings = df_cow_with_gis_mappings.sort_values('GISJOIN').reset_index()
df_cow_with_gis_mappings.drop_column('index')

# %%
df_cow_with_gis_mappings.drop_column('GISJOIN_og')

# %%
df_cow_with_gis_mappings
# Out:
#                   GISJOIN       p_id  sex  age
# 0           1000100201001        477    1   72
# 1           1000100201001        478    1   81
# 2           1000100201001        479    1   80
# 3           1000100201001        421    1   17
# 4           1000100201001        423    1   17
# ...                   ...        ...  ...  ...
# 243227903  56004509513003  308744465    0   93
# 243227904  56004509513003  308744466    0   96
# 243227905  56004509513003  308744467    0   92
# 243227906  56004509513003  308744468    0   85
# 243227907  56004509513003  308744469    0   92
#
# [243227908 rows x 4 columns]

# %%
df_cow_with_gis_mappings['GISJOIN_cow'] = df_cow.GISJOIN.values

# %%
df_cow_with_gis_mappings.query('GISJOIN != GISJOIN_cow')
# Out:
# Empty DataFrame
# Columns: [GISJOIN, p_id, sex, age, GISJOIN_cow]
# Index: []

# %%
df_cow_with_gis_mappings['cow'] = df_cow.cow.values

# %%
df_cow_with_gis_mappings.drop_column('GISJOIN_cow')
df_cow_with_gis_mappings.drop_column('GISJOIN')

# %%
df_cow_with_gis_mappings.cow.value_counts()
# Out:
# 0    161573949
# 3     19432921
# 2     19202718
# 6     15896895
# 4     11522611
# 1      8509315
# 5      6529395
# 7       560104
# Name: cow, dtype: int32

# %%
del(df_cow)

# %% [markdown]
# ### merge sex and cow with lat-long table

# %%
df_cow_with_gis_mappings
# Out:
#                 p_id  sex  age  cow
# 0                477    1   72    0
# 1                478    1   81    0
# 2                479    1   80    0
# 3                421    1   17    0
# 4                423    1   17    0
# ...              ...  ...  ...  ...
# 243227903  308744465    0   93    6
# 243227904  308744466    0   96    6
# 243227905  308744467    0   92    6
# 243227906  308744468    0   85    6
# 243227907  308744469    0   92    6
#
# [243227908 rows x 4 columns]

# %%
df = df.merge(df_cow_with_gis_mappings, on='p_id', how='left')

# %%
df
# Out:
#                      GISJOIN             x             y  sex_x       p_id  \
# 0           1000100203001009 -9.624182e+06  3.826258e+06      0       5088
# 1           1000100203001009 -9.624108e+06  3.826253e+06      0       5089
# 2           1000100203001009 -9.624094e+06  3.826276e+06      0       5090
# 3           1000100203001009 -9.624169e+06  3.826045e+06      0       5091
# 4           1000100203001009 -9.624141e+06  3.826127e+06      0       5092
# ...                      ...           ...           ...    ...        ...
# 308745304  56004109752003864 -1.227103e+07  5.061271e+06      0  308712265
# 308745305  56004109752003864 -1.227072e+07  5.062986e+06      0  308712266
# 308745306  56004109752003864 -1.227213e+07  5.063594e+06      0  308712267
# 308745307  56004109752003864 -1.227194e+07  5.061883e+06      0  308712268
# 308745308  56004109752003864 -1.227180e+07  5.063851e+06      0  308712269
#
#            age_x  education  income sex_y age_y   cow
# 0             13         16      20  null  null  null
# 1             12         16      20  null  null  null
# 2             13         16      20  null  null  null
# 3             10         16      20  null  null  null
# 4             12         16      20  null  null  null
# ...          ...        ...     ...   ...   ...   ...
# 308745304     10         16      20  null  null  null
# 308745305     11         16      20  null  null  null
# 308745306     11         16      20  null  null  null
# 308745307     11         16      20  null  null  null
# 308745308     13         16      20  null  null  null
#
# [308745309 rows x 11 columns]

# %%
df.drop_column('age_y')
df.drop_column('sex_y')

# %%
df.cow = df.cow.fillna(8)
df.rename({
    'sex_x':'sex',
    'age_x': 'age'
}, inplace=True)

# %%
df.dtypes
# Out:
# GISJOIN        int64
# x            float64
# y            float64
# sex             int8
# p_id           int32
# age             int8
# education       int8
# income          int8
# cow             int8
# dtype: object

# %%
del(df_cow_with_gis_mappings)

# %%
df
# Out:
#                      GISJOIN             x             y  sex       p_id  age  \
# 0           1000100203001009 -9.624182e+06  3.826258e+06    0       5088   13
# 1           1000100203001009 -9.624108e+06  3.826253e+06    0       5089   12
# 2           1000100203001009 -9.624094e+06  3.826276e+06    0       5090   13
# 3           1000100203001009 -9.624169e+06  3.826045e+06    0       5091   10
# 4           1000100203001009 -9.624141e+06  3.826127e+06    0       5092   12
# ...                      ...           ...           ...  ...        ...  ...
# 308745304  56004109752003864 -1.227103e+07  5.061271e+06    0  308712265   10
# 308745305  56004109752003864 -1.227072e+07  5.062986e+06    0  308712266   11
# 308745306  56004109752003864 -1.227213e+07  5.063594e+06    0  308712267   11
# 308745307  56004109752003864 -1.227194e+07  5.061883e+06    0  308712268   11
# 308745308  56004109752003864 -1.227180e+07  5.063851e+06    0  308712269   13
#
#            education  income  cow
# 0                 16      20    8
# 1                 16      20    8
# 2                 16      20    8
# 3                 16      20    8
# 4                 16      20    8
# ...              ...     ...  ...
# 308745304         16      20    8
# 308745305         16      20    8
# 308745306         16      20    8
# 308745307         16      20    8
# 308745308         16      20    8
#
# [308745309 rows x 9 columns]

# %%
df.to_parquet('../data/all_states_lat_long_cow_income_education_age_sex.parquet')
# Out:
# /home/ajay/anaconda3/envs/rapids_dev_0.12/lib/python3.6/site-packages/cudf/io/parquet.py:70: UserWarning: Using CPU via PyArrow to write Parquet dataset, this will be GPU accelerated in the future
#   "Using CPU via PyArrow to write Parquet dataset, this will "
